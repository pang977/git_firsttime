# %%
print('test file')
# Out:
# test file

# %% [markdown]
# # git init
#
# สร้าง repository ลงใน local (เครื่องของเรา)
#
# # touch <filename>.<นามสกุลไฟล์>
#
# การสร้างไฟล์
#
# # git add
#
# - git add <filename> : การนำเข้าไฟล์ทีละไฟล์ตามชื่อไฟล์
#
# - git add *.<นามสกุลไฟล์> : การเพิ่มหลายไฟล์ด้วยการใช้นามสกุลไฟล์
#
# - git add . : การเพิ่มไฟล์ที่อยู่ในโฟลเดอร์ (ภายใน directory ที่เราอยู่)
#
# # git rm
#
# - git rm -r --cached . : ลบทั้งหมดออกจาก repository
#
# - git rm --cached <filename> : ลบแค่ไฟล์ที่เราเลือก
#
# # git status
#
# ดูสถานะการทำงาน การเปลี่ยนแปลงของแต่ละไฟล์
#
# # git commit -m "ข้อความที่จะบันทึก"
#
# เป็นการเก็บประวัติการแก้ไข พร้อมคำอธิบาย
#
# # git log
#
# - git log : การดูประวัติทั่วๆ ไปจะเห็นรายละเอียดเยอะ
#
# - git log --oneline : ประวัติจะถูกย่อสั้นๆ พร้อมรหัสการแก้ไข(เวอร์ชั่น)
#
# - git log graph : แสดงประวัติออกมาเป็นเส้นให้ดูง่ายๆ
#
# # git diff <commit_id> <commit_id>
#
# การเปรียบเทียบประวัติการแก้ไขของ 2 เวอร์ชั่น
#
# # git checkout <filename>
#
# การคืนค่าเวอร์ชั่นล่าสุดกลับไปเป็นเวอร์ชั่นก่อนหน้า
#
# # git reset
#
# ย้อนค่าการแก้ไขให้ไปอยู่ในสภาพก่อน add เวอร์ชั่นต่างๆ
#
# - git reset --option(เลือกใช้ : soft (กลับมายัง staging) / mixed (กลับมายัง working) / hard (ทำลายทิ้ง) ) <commit_id?ี่ต้องการย้อน>
#
# # git branch
#
# - git branch : แสดง Branch
#
# - git chackout -b <branchname> : สลับ Branch และสร้างใหม่
#
# - git branch -d <branchname> : ลบ
#
# - git checkout <branchname> : สลับ branch
#
# - git checkout master : สลับไปอันหลัก
#
# - git merge <branchname> : การรวม branch
#
# # git (up to github)
#
# การส่งงานในคอมขึ้น github และดูรายละเอียดการแก้ไขได้
#
# - git add
#
# - git commit -m ""
#
# - git branch -M main
#
# - git remote add origin https://github.com/pang977/test_git.git
#
# - git push -u origin main
#
# # git pull
#
# การดึงงานจาก github ลงมาทำงานต่อในเครื่องของเรา
#
# - git pull : กรณีที่ github เชื่อมต่อกันอยู่แล้วระบบจะทำการเพิ่มเติมให้อัตโนมัติ
#
# # README.md
#
# บอกรายละเอียดของโปรเจค
#
# # git push
#
# การอัพเดทงานในเครื่องขึ้น github แบบทำต่อเพิ่มแล้วต้องอัพเดทงาน
#
# # git clone
#
# ลูกทีมต้องการทำโปรเจคหรือต่อยอดงาน ไม่ส่งผลกระทบต่อ github
#
# - copy from HTTPS ---> click right git bash
#
# - git clone <HTTPS>
